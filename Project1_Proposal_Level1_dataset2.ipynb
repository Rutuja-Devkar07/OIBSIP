# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/devka/OneDrive/Documents/menu.csv")

# %%
data.head(10)
# Out:
#     Category                                               Item  \
# 0  Breakfast                                       Egg McMuffin
# 1  Breakfast                                  Egg White Delight
# 2  Breakfast                                   Sausage McMuffin
# 3  Breakfast                          Sausage McMuffin with Egg
# 4  Breakfast                   Sausage McMuffin with Egg Whites
# 5  Breakfast                               Steak & Egg McMuffin
# 6  Breakfast      Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7  Breakfast        Bacon, Egg & Cheese Biscuit (Large Biscuit)
# 8  Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (R...
# 9  Breakfast  Bacon, Egg & Cheese Biscuit with Egg Whites (L...
#
#      Serving Size  Calories  Calories from Fat  Total Fat  \
# 0  4.8 oz (136 g)       300                120       13.0
# 1  4.8 oz (135 g)       250                 70        8.0
# 2  3.9 oz (111 g)       370                200       23.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
data.shape
# Out:
# (260, 24)

# %%
data.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
data.isnull().sum()/data.shape[0]*100
# Out:
# Category                         0.0
# Item                             0.0
# Serving Size                     0.0
# Calories                         0.0
# Calories from Fat                0.0
# Total Fat                        0.0
# Total Fat (% Daily Value)        0.0
# Saturated Fat                    0.0
# Saturated Fat (% Daily Value)    0.0
# Trans Fat                        0.0
# Cholesterol                      0.0
# Cholesterol (% Daily Value)      0.0
# Sodium                           0.0
# Sodium (% Daily Value)           0.0
# Carbohydrates                    0.0
# Carbohydrates (% Daily Value)    0.0
# Dietary Fiber                    0.0
# Dietary Fiber (% Daily Value)    0.0
# Sugars                           0.0
# Protein                          0.0
# Vitamin A (% Daily Value)        0.0
# Vitamin C (% Daily Value)        0.0
# Calcium (% Daily Value)          0.0
# Iron (% Daily Value)             0.0
# dtype: float64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
for i in data.select_dtypes(include="object").columns:
   print(data[i].value_counts())
print('***'*10)
# Out:
# Category
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: count, dtype: int64
# Item
# McFlurry with Reese's Peanut Butter Cups (Snack)                 1
# Egg McMuffin                                                     1
# Egg White Delight                                                1
# Sausage McMuffin                                                 1
# Vanilla Shake (Large)                                            1
#                                                                 ..
# Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)    1
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                      1
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                    1
# Steak & Egg McMuffin                                             1
# ...

# %%
#descriptive statistics
data.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
#histogram 
for i in data.select_dtypes(include="number").columns:
    sns.histplot(data=data, x=i)
    plot.show()

# %%
# Basic descriptive statistics for numerical columns
print(data.describe())

# Specific statistics
mean_calories = data['Calories'].mean()
median_calories = data['Calories'].median()
mode_calories = data['Calories'].mode()[0]
std_calories = data['Calories'].std()

print(f"Mean: {mean_calories}, Median: {median_calories}, Mode: {mode_calories}, Standard Deviation: {std_calories}")
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %% [markdown]
# ###data visualization

# %%
# Histogram for Calories
plot.figure(figsize=(6, 6))
sns.histplot(data['Calories'], kde=True, bins=20)
plot.title('Distribution of Calories')
plot.xlabel('Calories')
plot.ylabel('Frequency')
plot.show()

# %%
plot.figure(figsize=(8, 6))
sns.scatterplot(x='Total Fat', y='Calories', data=data)
plot.title('Total Fat vs Calories')
plot.xlabel('Total Fat (g)')
plot.ylabel('Calories')
plot.show()

# %%
# Total Calories per Category
category_sales = data.groupby('Category')['Calories'].sum().sort_values(ascending=False)

plot.figure(figsize=(10, 6))
sns.barplot(x=category_sales.index, y=category_sales.values)
plot.title('Total Calories by Category')
plot.xticks(rotation=45)
plot.ylabel('Total Calories')
plot.show()

# Top 10 items with the highest calories
top_items = data[['Item', 'Calories']].sort_values(by='Calories', ascending=False).head(10)
print(top_items)
# Out:
#                                                   Item  Calories
# 82                        Chicken McNuggets (40 piece)      1880
# 32         Big Breakfast with Hotcakes (Large Biscuit)      1150
# 31       Big Breakfast with Hotcakes (Regular Biscuit)      1090
# 34   Big Breakfast with Hotcakes and Egg Whites (La...      1050
# 33   Big Breakfast with Hotcakes and Egg Whites (Re...       990
# 81                        Chicken McNuggets (20 piece)       940
# 253               McFlurry with M&M’s Candies (Medium)       930
# 249                            Chocolate Shake (Large)       850
# 246                           Strawberry Shake (Large)       850
# 251                             Shamrock Shake (Large)       820

# %%
# Histogram for Calories
plot.figure(figsize=(8, 6))
sns.histplot(data['Calories'], kde=True, bins=20)
plot.title('Distribution of Calories')
plot.xlabel('Calories')
plot.ylabel('Frequency')
plot.show()

# %% [markdown]
# #Recommendations

# %% [markdown]
# #Healthier Options: Introduce and promote lower-calorie alternatives in categories with high-fat or high-calorie items.
#
# #Popular Items: Optimize high-calorie favorites by either promoting them as indulgent treats or reducing their calorie content for a healthier version.
#
# #Clear Labels: Highlight items rich in fiber, low in trans fats, and nutritionally balanced to guide healthier choices.
